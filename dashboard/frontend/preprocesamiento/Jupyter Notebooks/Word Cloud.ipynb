# %% [markdown]
# # Word Cloud

# %%
from pathlib import Path, PurePath
from wordcloud import WordCloud
import matplotlib.pyplot as plt
import pandas as pd

# %%
ruta_actual = PurePath(Path.cwd()).parent
archivo = ruta_actual / 'TestData' / 'Output' / 'prediccion.csv'

# %%
pred_df = pd.read_csv(archivo, encoding='ISO-8859-1')

# %%
pred_df.head()
# Out:
#             Author                 Date  \
# 0  zhafranzainal11  2019-11-16 07:00:19
# 1     DH27sentinel  2019-11-16 07:00:26
# 2  ChaoticTimelord  2019-11-16 07:00:30
# 3          DezWtff  2019-11-16 07:00:38
# 4         Junkifyy  2019-11-16 07:00:39
#
#                                                 Text Sentiment
# 0  My son called me Boomer today, I had to explai...  negativo
# 1  If your one of those ooooh I found an RPG I'm ...  negativo
# 2           Squad. #Fortnite https://t.co/lU8oPf26ms   neutral
# 3  Fortnite Poem Freshman Year For a Final got an...   neutral
# 4  Quit Fortnite last week &amp; tbh haven't felt...  negativo

# %%
ruta_actual = PurePath(Path.cwd()).parent
archivo = ruta_actual / 'TestData' / 'Output' / 'prediccion_wordcloud.csv'
pred_wordcloud_df = pd.read_csv(archivo, encoding='ISO-8859-1')
pred_wordcloud_df["sentiment"] = pred_df["Sentiment"]
pred_wordcloud_df.head()
# Out:
#                                      data_lemmatized sentiment
# 0  my son call me boomer today i have to explain ...  negativo
# 1  if your one of those ooh i find an rpg i be ju...  negativo
# 2                                              squad   neutral
# 3  fortnite poem freshman year for a final get an...   neutral
# 4  quit fortnite last week amp tbh have not felt ...  negativo

# %%
pred_pos = pred_wordcloud_df[pred_df['Sentiment'] == 'positivo']
pred_neg = pred_wordcloud_df[pred_df['Sentiment'] == 'negativo']
pred_neu = pred_wordcloud_df[pred_df['Sentiment'] == 'neutral']

# %%
print(pred_pos.shape[0])
print(pred_neg.shape[0])
print(pred_neu.shape[0])
# Out:
# 9
# 22
# 24

# %%
text = pred_wordcloud_df.data_lemmatized.values
wordcloud = WordCloud(background_color = 'white').generate(str(text))

# %% [markdown]
# ## General

# %%
plt.imshow(wordcloud, interpolation = 'bilinear')
plt.axis('off')
plt.tight_layout(pad=0)
plt.show()

# %% [markdown]
# ## Positivos

# %%
text = pred_pos.data_lemmatized.values
wordcloud = WordCloud(background_color = 'white').generate(str(text))
plt.imshow(wordcloud, interpolation = 'bilinear')
plt.axis('off')
plt.tight_layout(pad=0)
plt.show()

# %% [markdown]
# ## Negativos

# %%
text = pred_neg.data_lemmatized.values
wordcloud = WordCloud(background_color = 'white').generate(str(text))
plt.imshow(wordcloud, interpolation = 'bilinear')
plt.axis('off')
plt.tight_layout(pad=0)
plt.show()

# %% [markdown]
# ## Neutros

# %%
text = pred_neu.data_lemmatized.values
wordcloud = WordCloud(background_color = 'white').generate(str(text))
plt.imshow(wordcloud, interpolation = 'bilinear')
plt.axis('off')
plt.tight_layout(pad=0)
plt.show()
